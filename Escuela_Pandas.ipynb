# %% [markdown]
# # **Escuela**

# %% [markdown]
# En este proyecto, hemos llevado a cabo un proceso de recopilación y análisis de datos para proporcionar información clave sobre los alumnos inscritos en cursos. Nuestra labor abarca diversas etapas, desde la obtención de nombres hasta la creación de un informe exportado en formato Excel.
#
# **Fase 1 Recopilación de Nombres:**
# Comenzamos extrayendo 400 nombres de una API, distribuidos equitativamente entre 200 nombres masculinos y 200 femeninos. Luego, combinamos estos nombres en un solo DataFrame, lo que nos permitió realizar un análisis más completo de la información.
#
# * **Ampliación de la Información:** Posteriormente, enriquecimos nuestro DataFrame al agregar nuevas columnas para proporcionar más información sobre cada alumno. Esto incluyó detalles como matricula, id, email y cualquier otro atributo que consideramos relevante.
#
# **Fase 2 Datos de Cursos:** Adicionalmente, creamos otro DataFrame que obtuvo datos desde una URL específica. Este DataFrame contenía información sobre los cursos ofrecidos por la escuela, incluyendo el nombre del curso.
#
# **Fase 3 Relación y Generación de Reporte:** Uno de los aspectos más importantes de nuestro proyecto fue establecer una relación entre los dos DataFrames: el de los alumnos y el de los cursos. Esto nos permitió determinar qué alumnos estaban inscritos en cada curso, lo que es fundamental para la toma de decisiones.
#
# **Fase 4 Creación de Reporte:** Finalmente, creamos un informe detallado que presenta la información sobre los alumnos inscritos en un curso en especifico.
#
# **Fase 5 Exportación en Formato Excel:** El informe generado en la fase anterior se exportó en formato Excel. Esto permite compartir la información de manera efectiva, facilitando la toma de decisiones y la planificación académica.
#
# En conjunto, este proyecto ilustra cómo los datos y la tecnología pueden utilizarse para mejorar la gestión y la toma de decisiones en una institución educativa. El proceso abarca desde la recopilación y análisis de datos hasta la generación de informes y su distribución en un formato accesible.

# %% [markdown]
# # **Bibliotecas**.

# %% [markdown]
# **Organizando nuestro entorno de trabajo**

# %%
# Importaciones para análisis de datos
import pandas as pd
import numpy as np

# Importación para procesamiento HTML
import html5lib

# Importaciones para visualización
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1. **import pandas as pd:** Importa la biblioteca Pandas y la renombra como 'pd'. Pandas es ampliamente utilizada para la manipulación y análisis de datos en Python.
#
# 2. **import numpy as np:** Importa la biblioteca NumPy y la renombra como 'np'. NumPy es útil para realizar operaciones matemáticas y manipulación de matrices en Python.
#
# 3. **import html5lib:** Importa la biblioteca html5lib. Esta biblioteca es utilizada para analizar y procesar documentos HTML.
#
# 4. **import seaborn as sns:** Importa la biblioteca Seaborn y la renombra como 'sns'. Seaborn es una biblioteca de visualización de datos que se basa en Matplotlib y facilita la creación de gráficos atractivos.
#
# 5. **import matplotlib.pyplot as plt:** Importa el módulo 'pyplot' de la biblioteca Matplotlib y lo renombra como 'plt'. Matplotlib es una biblioteca de visualización ampliamente utilizada en Python.

# %% [markdown]
# #**1.  Nombres**

# %% [markdown]
# Obtendremos el nombre de los alumnos de nuestra escuela desde la siguiente URL para comenzar a construir nuestra base de datos

# %% [markdown]
# https://raw.githubusercontent.com/ElProfeAlejo/tratamiento_datos_python/main/ranking.json

# %% [markdown]
# **Pandas**

# %% [markdown]
# * read

# %%
# Lee un archivo JSON desde una URL y almacena los datos en un DataFrame llamado 'df'
df = pd.read_json("https://raw.githubusercontent.com/ElProfeAlejo/tratamiento_datos_python/main/ranking.json")

# Filtra el DataFrame 'df' para seleccionar solo las filas donde la columna 'sexo' es igual a 'M' (sexo masculino),
# luego toma una muestra aleatoria de 200 de estas filas y almacénalas en el DataFrame 'nombres_m'
nombres_m = df[df['sexo'] == 'M'].sample(200)

# Filtra el DataFrame 'df' para seleccionar solo las filas donde la columna 'sexo' es igual a 'F' (sexo femenino),
# luego toma una muestra aleatoria de 200 de estas filas y almacénalas en el DataFrame 'nombres_f'
nombres_f = df[df['sexo'] == 'F'].sample(200)

# Imprime el DataFrame 'nombres_f', que contiene los nombres de las mujeres muestreados aleatoriamente
nombres_f
# Out:
#            nome  regiao    freq  rank sexo
# 353      CLEIDE       0  105492   154    F
# 364      MARISA       0   95961   165    F
# 326  SEBASTIANA       0  128064   127    F
# 226        RITA       0  354720    27    F
# 221        VERA       0  376202    22    F
# ..          ...     ...     ...   ...  ...
# 214     JESSICA       0  456472    15    F
# 323       IVONE       0  131256   124    F
# 334    VERONICA       0  119496   135    F
# 333      BRENDA       0  120624   134    F
# 271       MARTA       0  214263    72    F
#
# [200 rows x 5 columns]

# %%
# Imprime el DataFrame 'nombres_m', que contiene los nombres de los hombres muestreados aleatoriamente
nombres_m
# Out:
#            nome  regiao     freq  rank sexo
# 188    VALDECIR       0    71383   189    M
# 102       HELIO       0   137138   103    M
# 56      DOUGLAS       0   264889    57    M
# 8          LUIZ       0  1102927     9    M
# 116    DOMINGOS       0   125252   117    M
# ..          ...     ...      ...   ...  ...
# 164       JAIRO       0    78445   165    M
# 176       CELIO       0    74693   177    M
# 169  WELLINGTON       0    76820   170    M
# 1          JOAO       0  2971935     2    M
# 38        DIEGO       0   421973    39    M
#
# [200 rows x 5 columns]

# %%
# Imprime un mensaje que incluye la cantidad total de nombres en los DataFrames 'nombres_m' y 'nombres_f'
print('Cantidad de nombres: ' + str(len(nombres_m) + len(nombres_f)))
# Out:
# Cantidad de nombres: 400

# %% [markdown]
# El código toma la longitud (número de filas) de los DataFrames **nombres_m y nombres_f**, suma estos dos valores y luego los convierte en una cadena (string) para que puedan ser concatenados con el mensaje. El resultado es un mensaje que muestra la cantidad total de nombres contenidos en ambos DataFrames.

# %%
# Crea una lista llamada 'frames' que contiene dos DataFrames: 'nombres_m' y 'nombres_f'
frames = [nombres_m, nombres_f]
frames
# Out:
# [           nome  regiao     freq  rank sexo
#  188    VALDECIR       0    71383   189    M
#  102       HELIO       0   137138   103    M
#  56      DOUGLAS       0   264889    57    M
#  8          LUIZ       0  1102927     9    M
#  116    DOMINGOS       0   125252   117    M
#  ..          ...     ...      ...   ...  ...
#  164       JAIRO       0    78445   165    M
#  176       CELIO       0    74693   177    M
#  169  WELLINGTON       0    76820   170    M
#  1          JOAO       0  2971935     2    M
#  38        DIEGO       0   421973    39    M
#
#  [200 rows x 5 columns],
#             nome  regiao    freq  rank sexo
#  353      CLEIDE       0  105492   154    F
#  364      MARISA       0   95961   165    F
#  326  SEBASTIANA       0  128064   127    F
#  226        RITA       0  354720    27    F
#  221        VERA       0  376202    22    F
#  ..          ...     ...     ...   ...  ...
#  214     JESSICA       0  456472    15    F
# ...

# %% [markdown]
# **Concatenando y renombrando**

# %%
# Concatena los DataFrames 'nombres_m' y 'nombres_f' en un solo DataFrame 'nombres'
nombres = pd.concat(frames)['nome'].to_frame()

# Con el método to_frame(), convertimos la serie resultante en un DataFrame
# y luego renombramos la columna a 'nombres'
nombres.columns = ['nombres']

# Muestra una muestra aleatoria de 5 filas del DataFrame 'nombres'
nombres.sample(5)
# Out:
#       nombres
# 145     ITALO
# 72   GILBERTO
# 327     TAINA
# 104  REINALDO
# 320   JOSIANE

# %% [markdown]
# 1. El código utiliza la función **pd.concat** para combinar los DataFrames **nombres_m** y **nombres_f** en uno solo, y selecciona la columna 'nome' en ese DataFrame resultante.
#
# 2. Luego, se utiliza el método **.to_frame()** para convertir el resultado en un DataFrame.
#
# 3. La columna se renombra a 'nombres' usando **nombres.columns = ['nombres'].**
#
# 4. Finalmente, se muestra una muestra aleatoria de 5 filas del DataFrame **nombres**.

# %% [markdown]
# **Numpy**

# %% [markdown]
# * np.random.seed

# %%
# Establece una semilla (seed) para la generación de números aleatorios
np.random.seed(123)

# Obtiene la longitud (número de filas) del DataFrame 'nombres', que representa el total de alumnos
total_alumnos = len(nombres)

total_alumnos
# Out:
# 400

# %% [markdown]
# 1. Se establece la semilla (seed) para el generador de números aleatorios en 123. Esto garantiza que, al utilizar funciones aleatorias de NumPy, obtendrás los mismos resultados cada vez que ejecutes el código, lo que es útil para la reproducibilidad.
#
# 2. Se calcula la variable **total_alumnos** tomando la longitud (número de filas) del DataFrame **nombres**, lo que representa el número total de alumnos en tu muestra.

# %% [markdown]
# **Nueva columna (id_alumno)**

# %% [markdown]
# * np.random.permutation

# %%
# Agrega una nueva columna 'id_alumno' al DataFrame 'nombres'
# La columna 'id_alumno' contendrá permutaciones aleatorias de números del 1 al total de alumnos
nombres['id_alumno'] = np.random.permutation(total_alumnos) + 1

# Muestra una muestra aleatoria de 5 filas del DataFrame 'nombres' con la columna 'id_alumno' recién añadida
nombres.sample(5)
# Out:
#      nombres  id_alumno
# 109    CELSO        369
# 96   EVERTON        303
# 226     RITA        382
# 329   MIRIAN         33
# 348   JANETE        111

# %% [markdown]
# 1. Se utiliza **np.random.permutation** para generar una permutación aleatoria de números del 1 al número total de alumnos **(total_alumnos)**, y luego se suma 1 a cada valor para obtener un rango de ID de alumno que comienza en 1.
#
# 2. Se agrega esta permutación como una nueva columna llamada 'id_alumno' al DataFrame **nombres**.
#
# 3. Finalmente, se muestra una muestra aleatoria de 5 filas del DataFrame actualizado, que ahora incluye la columna 'id_alumno'. Cada fila muestra un nombre y su respectivo ID de alumno asignado de manera aleatoria

# %% [markdown]
# **Nueva columna (dominio)**

# %% [markdown]
# * np.random.choice

# %%
# Define una lista de dominios de correo electrónico
dominios = ['@dominiodemail.com', '@serviciodeemail.com']

# Agrega una nueva columna 'dominio' al DataFrame 'nombres'
# La columna 'dominio' contiene dominios de correo electrónico seleccionados aleatoriamente de la lista de dominios
nombres['dominio'] = np.random.choice(dominios, total_alumnos)

# Muestra una muestra aleatoria de 5 filas del DataFrame 'nombres' con la columna 'dominio' recién añadida
nombres.sample(5)
# Out:
#        nombres  id_alumno               dominio
# 267      PAULA         78    @dominiodemail.com
# 353     CLEIDE        331  @serviciodeemail.com
# 375  ALEXANDRA        340    @dominiodemail.com
# 156   VALDEMAR        174    @dominiodemail.com
# 137    AUGUSTO         45    @dominiodemail.com

# %% [markdown]
# 1. Se define una lista llamada **dominios** que contiene dos opciones de dominios de correo electrónico.
#
# 2. Se utiliza **np.random.choice** para seleccionar aleatoriamente un dominio de la lista de **dominios** para cada fila en el DataFrame **nombres**.
#
# 3. El resultado se agrega como una nueva columna llamada 'dominio' al DataFrame **nombres**.
#
# 4. Finalmente, se muestra una muestra aleatoria de 5 filas del DataFrame actualizado, que ahora incluye la columna 'dominio'. Cada fila muestra un nombre, un ID de alumno y un dominio de correo electrónico asignado de manera aleatoria

# %% [markdown]
# **Nueva columna (email)**

# %% [markdown]
# * str.lower()

# %%
# Crea una nueva columna 'email' en el DataFrame 'nombres'
# Esta columna contiene direcciones de correo electrónico construidas concatenando los nombres y los dominios en minúsculas
nombres['email'] = nombres.nombres.str.cat(nombres.dominio).str.lower()

# Muestra una muestra aleatoria de 5 filas del DataFrame 'nombres' con la columna 'email' recién creada
nombres.sample(5)
# Out:
#        nombres  id_alumno               dominio                        email
# 391     TERESA        320    @dominiodemail.com     teresa@dominiodemail.com
# 96     EVERTON        303  @serviciodeemail.com  everton@serviciodeemail.com
# 135     RUBENS        221    @dominiodemail.com     rubens@dominiodemail.com
# 27   GUILHERME          8    @dominiodemail.com  guilherme@dominiodemail.com
# 133       RUAN        137    @dominiodemail.com       ruan@dominiodemail.com

# %% [markdown]
# 1. Se utiliza el método **.str.cat()** para concatenar las columnas 'nombres' y 'dominio' en cada fila del DataFrame **nombres**. Esto crea una nueva serie de cadenas que contiene las direcciones de correo electrónico en forma de 'nombres@dominio'.
#
# 2. Luego, se utiliza **.str.lower()** para convertir todas las letras en la serie resultante en minúsculas, de modo que las direcciones de correo electrónico estén en minúsculas.
#
# 3. El resultado se almacena en una nueva columna llamada 'email' en el DataFrame **nombres**.
#
# 4. Finalmente, se muestra una muestra aleatoria de 5 filas del DataFrame actualizado, que ahora incluye la columna 'email' con las direcciones de correo electrónico en minúsculas.

# %% [markdown]
# **Nota:** ¿Qué debo hacer para leer un json que está en mi máquina local y no en una página web? Para leer un json que está en la máquina local y no en la web, en lugar de pasar la dirección web como parámetro, pasamos el camino del archivo en nuestra máquina.

# %%
nombres
# Out:
#       nombres  id_alumno               dominio                         email
# 188  VALDECIR        235    @dominiodemail.com    valdecir@dominiodemail.com
# 102     HELIO         43  @serviciodeemail.com     helio@serviciodeemail.com
# 56    DOUGLAS        304  @serviciodeemail.com   douglas@serviciodeemail.com
# 8        LUIZ        156    @dominiodemail.com        luiz@dominiodemail.com
# 116  DOMINGOS        343  @serviciodeemail.com  domingos@serviciodeemail.com
# ..        ...        ...                   ...                           ...
# 214   JESSICA        231    @dominiodemail.com     jessica@dominiodemail.com
# 323     IVONE         99  @serviciodeemail.com     ivone@serviciodeemail.com
# 334  VERONICA        323    @dominiodemail.com    veronica@dominiodemail.com
# 333    BRENDA        383    @dominiodemail.com      brenda@dominiodemail.com
# 271     MARTA        366  @serviciodeemail.com     marta@serviciodeemail.com
#
# [400 rows x 4 columns]

# %% [markdown]
# **Nueva columna (matricula)**

# %% [markdown]
# * np.ceil()
# * np.random.exponential()

# %%
# Agrega una nueva columna 'matricula' al DataFrame 'nombres'
# Genera valores aleatorios usando una distribución exponencial,
# los redondea hacia arriba y los convierte en números enteros
nombres['matricula'] = np.ceil(np.random.exponential(size=total_alumnos) * 1.5).astype(int)
nombres.head()
# Out:
#       nombres  id_alumno               dominio                         email  \
# 188  VALDECIR        235    @dominiodemail.com    valdecir@dominiodemail.com
# 102     HELIO         43  @serviciodeemail.com     helio@serviciodeemail.com
# 56    DOUGLAS        304  @serviciodeemail.com   douglas@serviciodeemail.com
# 8        LUIZ        156    @dominiodemail.com        luiz@dominiodemail.com
# 116  DOMINGOS        343  @serviciodeemail.com  domingos@serviciodeemail.com
#
#      matricula
# 188          1
# 102          1
# 56           5
# 8            5
# 116          1

# %% [markdown]
# 1. **np.random.exponential(size=total_alumnos)** genera una serie de números aleatorios siguiendo una distribución exponencial.
#
# 2. **1.5** multiplica cada valor por 1.5.
#
# 3. **np.ceil()** redondea cada valor hacia arriba al número entero más cercano.
#
# 4. **.astype(int)** convierte los valores resultantes en números enteros.

# %% [markdown]
# La función **describe()** en pandas se utiliza para obtener estadísticas descriptivas de un DataFrame, como el recuento, la media, la desviación estándar, el valor mínimo, el percentil 25, el percentil 50 (mediana), el percentil 75 y el valor máximo para cada columna numérica en el DataFrame.

# %%
nombres.describe()
# Out:
#         id_alumno   matricula
# count  400.000000  400.000000
# mean   200.500000    2.135000
# std    115.614301    1.515757
# min      1.000000    1.000000
# 25%    100.750000    1.000000
# 50%    200.500000    2.000000
# 75%    300.250000    3.000000
# max    400.000000   12.000000

# %% [markdown]
# * **count:** El número de filas en la columna (en este caso, 400).
#
# * **mean:** La media de los valores en la columna.
#
# * **std:** La desviación estándar de los valores.
#
# * **min:** El valor mínimo en la columna.
#
# * **25%:** El percentil 25, que es el valor por debajo del cual caen el 25% de los datos.
#
# * **50%:** El percentil 50, que es la mediana, es decir, el valor que divide la distribución en dos mitades iguales.
#
# * **75%:** El percentil 75, que es el valor por debajo del cual caen el 75% de los datos.
#
# * **max:** El valor máximo en la columna.

# %% [markdown]
# El código **nombres.matricula.describe()** se utiliza para obtener estadísticas descriptivas específicas de la columna 'matricula' en el DataFrame **nombres**

# %%
nombres.matricula.describe()
# Out:
# count    400.000000
# mean       2.135000
# std        1.515757
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       12.000000
# Name: matricula, dtype: float64

# %% [markdown]
# **Grafico de la Matricula**

# %% [markdown]
# La expresión **nombres.matricula.value_counts()** se utiliza para contar la frecuencia de cada valor único en la columna 'matricula' del DataFrame **nombres**. Devolverá una serie que muestra cuántas veces aparece cada valor único en esa columna.

# %%
nombres.matricula.value_counts()
# Out:
# 1     184
# 2      97
# 3      56
# 4      34
# 5      19
# 6       5
# 12      2
# 8       2
# 7       1
# Name: matricula, dtype: int64

# %%
# Crear un gráfico de barras para la columna 'matricula'
sns.set(style="whitegrid")  # Estilo de fondo
plt.figure(figsize=(10, 6))  # Tamaño de la figura

# Utiliza sns.countplot para crear el gráfico de barras
sns.countplot(data=nombres, x='matricula')

# Personalizar etiquetas y título del gráfico
plt.xlabel('Matrícula')
plt.ylabel('Frecuencia')
plt.title('Distribución de Matrícula')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 1. Importamos Seaborn y Matplotlib para crear y personalizar el gráfico.
#
# 2. Configuramos un estilo de fondo utilizando **sns.set(style="whitegrid")** para mejorar la apariencia del gráfico.
#
# 3. Especificamos el tamaño de la figura con **plt.figure(figsize=(10, 6)).**
#
# 4. Utilizamos **sns.countplot** para crear el gráfico de barras, pasando el DataFrame **nombres** y la columna 'matricula'.
#
# 5. Personalizamos las etiquetas del eje x y del eje y, así como el título del gráfico.
#
# 6. Mostramos el gráfico utilizando **plt.show().**

# %% [markdown]
# **Nuestro dataframe de nombres está completo**

# %%
nombres
# Out:
#       nombres  id_alumno               dominio                         email  \
# 188  VALDECIR        235    @dominiodemail.com    valdecir@dominiodemail.com
# 102     HELIO         43  @serviciodeemail.com     helio@serviciodeemail.com
# 56    DOUGLAS        304  @serviciodeemail.com   douglas@serviciodeemail.com
# 8        LUIZ        156    @dominiodemail.com        luiz@dominiodemail.com
# 116  DOMINGOS        343  @serviciodeemail.com  domingos@serviciodeemail.com
# ..        ...        ...                   ...                           ...
# 214   JESSICA        231    @dominiodemail.com     jessica@dominiodemail.com
# 323     IVONE         99  @serviciodeemail.com     ivone@serviciodeemail.com
# 334  VERONICA        323    @dominiodemail.com    veronica@dominiodemail.com
# 333    BRENDA        383    @dominiodemail.com      brenda@dominiodemail.com
# 271     MARTA        366  @serviciodeemail.com     marta@serviciodeemail.com
#
#      matricula
# 188          1
# ...

# %% [markdown]
# # **2. Cursos**

# %% [markdown]
# Obtendremos información sobre los cursos de nuestra escuela desde la siguiente URL para comenzar a construir nuestra base de datos.

# %% [markdown]
# * pd.read_html

# %%
# URL del sitio web que contiene la tabla que deseas leer
url = 'https://www.tiobe.com/tiobe-index/'

# Utiliza pd.read_html para intentar leer todas las tablas de la página web especificada
# Esto devuelve una lista de DataFrames, donde cada DataFrame representa una tabla encontrada en la página
cursos = pd.read_html(url)

# %% [markdown]
# El comando read_html() lee una tabla en una página html y su resultado es del tipo List. Cuando leemos con el comando read_html(), el resultado de esta función es del tipo List.

# %%
type(cursos)
# Out:
# list

# %%
# Selecciona la tercera tabla (índice 2) de la lista de DataFrames 'cursos'
# y luego selecciona todas las filas (:), pero solo la primera columna (:1)
cursos = cursos[2].iloc[:, :1]

cursos
# Out:
#    Programming Language
# 0                Python
# 1                     C
# 2                   C++
# 3                  Java
# 4                    C#
# 5            JavaScript
# 6          Visual Basic
# 7                   PHP
# 8                   SQL
# 9     Assembly language
# 10          Objective-C
# 11                 Lisp
# 12       (Visual) Basic

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos.head()
# Out:
#   Programming Language
# 0               Python
# 1                    C
# 2                  C++
# 3                 Java
# 4                   C#

# %% [markdown]
# **Renombrando el índice 'Programming Language' a 'nombre_curso'**

# %%
# Utiliza el método 'rename' para cambiar el nombre de la columna 'Programming Language' a 'nombre_curso'
cursos = cursos.rename(columns={'Programming Language': 'nombre_curso'})
cursos
# Out:
#          nombre_curso
# 0              Python
# 1                   C
# 2                 C++
# 3                Java
# 4                  C#
# 5          JavaScript
# 6        Visual Basic
# 7                 PHP
# 8                 SQL
# 9   Assembly language
# 10        Objective-C
# 11               Lisp
# 12     (Visual) Basic

# %% [markdown]
# **Nueva columna (id_curso)**

# %%
# Agrega una nueva columna 'id' al DataFrame 'cursos'
# El valor de 'id' es el índice de la fila más 1 (se inicia en 1 en lugar de 0)
cursos['id_curso'] = cursos.index + 1
cursos
# Out:
#          nombre_curso  id_curso
# 0              Python         1
# 1                   C         2
# 2                 C++         3
# 3                Java         4
# 4                  C#         5
# 5          JavaScript         6
# 6        Visual Basic         7
# 7                 PHP         8
# 8                 SQL         9
# 9   Assembly language        10
# 10        Objective-C        11
# 11               Lisp        12
# 12     (Visual) Basic        13

# %% [markdown]
# **Reemplazar el índice del dataframe 'cursos' con el 'id_curso' que creamos previamente.**

# %%
# Utiliza el método 'set_index' para establecer la columna 'id' como el nuevo índice del DataFrame 'cursos'
cursos = cursos.set_index('id_curso')

# %%
# Nos muestra los primeros 5 datos del DataFrame
cursos.head()
# Out:
#          nombre_curso
# id_curso
# 1              Python
# 2                   C
# 3                 C++
# 4                Java
# 5                  C#

# %% [markdown]
# El atributo **shape** se utiliza para obtener las dimensiones (número de filas y columnas) de un DataFrame en pandas. En el caso de tu DataFrame cursos después de todas las operaciones que realizaste, puedes obtener sus dimensiones de la siguiente manera:

# %%
cursos.shape
# Out:
# (13, 1)

# %% [markdown]
# # **3. Relacion**

# %% [markdown]
# Vamos a establecer una relación entre nuestros dataframes. En el dataframe **nombres**, utilizaremos la columna **matrícula** para relacionarla con el dataframe **cursos** a través de la columna **id_curso**.

# %%
nombres.head()
# Out:
#       nombres  id_alumno               dominio                         email  \
# 188  VALDECIR        235    @dominiodemail.com    valdecir@dominiodemail.com
# 102     HELIO         43  @serviciodeemail.com     helio@serviciodeemail.com
# 56    DOUGLAS        304  @serviciodeemail.com   douglas@serviciodeemail.com
# 8        LUIZ        156    @dominiodemail.com        luiz@dominiodemail.com
# 116  DOMINGOS        343  @serviciodeemail.com  domingos@serviciodeemail.com
#
#      matricula
# 188          1
# 102          1
# 56           5
# 8            5
# 116          1

# %%
cursos.head()
# Out:
#          nombre_curso
# id_curso
# 1              Python
# 2                   C
# 3                 C++
# 4                Java
# 5                  C#

# %% [markdown]
# * np.random.rad()

# %%
# Generar valores aleatorios utilizando np.random.rand
x = np.random.rand(len(cursos))

# Calcular las probabilidades dividiendo cada valor aleatorio por la suma de todos los valores aleatorios
prob = x / sum(x)

# Imprimir las probabilidades
prob
# Out:
# array([1.88565820e-01, 2.86032794e-02, 9.53947578e-02, 4.75501689e-02,
#        1.71838592e-01, 9.34311177e-02, 3.12903740e-05, 6.04514914e-02,
#        4.67949773e-02, 1.72097211e-02, 1.22180418e-01, 7.75560088e-02,
#        5.03923581e-02])

# %% [markdown]
# 1. Se utiliza **np.random.rand(len(cursos))** para generar valores aleatorios en función de la cantidad de cursos. Esto crea un arreglo de números aleatorios entre 0 y 1.
#
# 2. Luego, se calculan las probabilidades dividiendo cada valor aleatorio por la suma de todos los valores aleatorios. Esto normaliza los valores y asigna probabilidades a cada identificador de curso en función de estos valores aleatorios.

# %% [markdown]
# * iterrws()

# %%
# Crear una lista llamada 'todas_matriculas' que contendrá las relaciones entre id_cursos y matrículas
todas_matriculas = []

# Iterar a través de las filas del DataFrame 'nombres' utilizando iterrows()
for index, row in nombres.iterrows():
    id_curso = row.id_alumno
    matriculas = row.matricula
    # Generar matrículas aleatorias para el alumno actual
    for i in range(matriculas):
        # Generar una matrícula aleatoria seleccionando un ID de curso con probabilidades definidas por 'prob'
        mat = [id_curso, np.random.choice(cursos.index, p=prob)]
        todas_matriculas.append(mat)

# Crear un DataFrame 'matriculas' a partir de la lista 'todas_matriculas' con las columnas 'id_alumno' e 'id_curso'
matriculas = pd.DataFrame(todas_matriculas, columns=['id_alumno', 'id_curso'])

# Mostrar las primeras filas del DataFrame 'matriculas'
matriculas.head()
# Out:
#    id_alumno  id_curso
# 0        235        12
# 1         43         4
# 2        304         1
# 3        304         5
# 4        304        12

# %% [markdown]
# * .groupby()
# * .count()

# %%
# Agrupa el DataFrame 'matriculas' por 'id_curso' y cuenta las matrículas para cada curso
matriculas_por_curso = matriculas.groupby('id_curso').count()
matriculas_por_curso
# Out:
#           id_alumno
# id_curso
# 1               172
# 2                18
# 3                98
# 4                43
# 5               123
# 6                83
# 7                 1
# 8                50
# 9                49
# 10               13
# 11              105
# 12               64
# 13               35

# %% [markdown]
# * .join()

# %%
# Une el DataFrame 'matriculas_por_curso' con la columna 'nombre_curso' del DataFrame 'cursos'
matriculas_por_curso = matriculas_por_curso.join(cursos['nombre_curso'])
matriculas_por_curso
# Out:
#           id_alumno       nombre_curso
# id_curso
# 1               172             Python
# 2                18                  C
# 3                98                C++
# 4                43               Java
# 5               123                 C#
# 6                83         JavaScript
# 7                 1       Visual Basic
# 8                50                PHP
# 9                49                SQL
# 10               13  Assembly language
# 11              105        Objective-C
# 12               64               Lisp
# 13               35     (Visual) Basic

# %% [markdown]
# * raname()

# %%
# Selecciona las columnas 'nombre_curso' e 'id_alumno' y las renombra a 'Total'
matriculas_por_curso = matriculas_por_curso[['nombre_curso', 'id_alumno']].rename(columns={'id_alumno': 'Total'})
matriculas_por_curso
# Out:
#                nombre_curso  Total
# id_curso
# 1                    Python    172
# 2                         C     18
# 3                       C++     98
# 4                      Java     43
# 5                        C#    123
# 6                JavaScript     83
# 7              Visual Basic      1
# 8                       PHP     50
# 9                       SQL     49
# 10        Assembly language     13
# 11              Objective-C    105
# 12                     Lisp     64
# 13           (Visual) Basic     35

# %% [markdown]
# * .sort_values()

# %%
# Ordena el DataFrame 'matriculas_por_curso' en orden descendente basado en la columna 'Total'
matriculas_por_curso = matriculas_por_curso.sort_values('Total', ascending=False)
matriculas_por_curso
# Out:
#                nombre_curso  Total
# id_curso
# 1                    Python    172
# 5                        C#    123
# 11              Objective-C    105
# 3                       C++     98
# 6                JavaScript     83
# 12                     Lisp     64
# 8                       PHP     50
# 9                       SQL     49
# 4                      Java     43
# 13           (Visual) Basic     35
# 2                         C     18
# 10        Assembly language     13
# 7              Visual Basic      1

# %% [markdown]
# **Grafico**

# %%
matriculas_por_curso
# Out:
#                nombre_curso  Total
# id_curso
# 1                    Python    172
# 5                        C#    123
# 11              Objective-C    105
# 3                       C++     98
# 6                JavaScript     83
# 12                     Lisp     64
# 8                       PHP     50
# 9                       SQL     49
# 4                      Java     43
# 13           (Visual) Basic     35
# 2                         C     18
# 10        Assembly language     13
# 7              Visual Basic      1

# %%
# Crear un gráfico de barras
sns.set(style="whitegrid")  # Estilo de fondo
plt.figure(figsize=(10, 6))  # Tamaño de la figura

sns.barplot(data=matriculas_por_curso, x='nombre_curso', y='Total')

# Personalizar etiquetas y título del gráfico
plt.xlabel('Nombre del Curso')
plt.ylabel('Total de Matrículas')
plt.title('Matrículas por Curso')

# Rotar las etiquetas del eje x para mejorar la legibilidad
plt.xticks(rotation=45)  # Ajusta el ángulo de rotación

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # **4. Reporte**

# %% [markdown]
# Generar un buen reporte es esencial en una variedad de contextos profesionales y académicos. Aquí se describen algunas razones clave para la importancia de crear un informe de calidad:
#
# 1. **Comunicación Efectiva:** Los reportes son una forma efectiva de comunicar información de manera clara y concisa a colegas, superiores, clientes u otros interesados. Un buen informe facilita la comprensión de datos, hallazgos, resultados y recomendaciones.
#
# 2. **Toma de Decisiones Informadas:** Los reportes proporcionan la base necesaria para tomar decisiones informadas. La presentación de datos y análisis en un informe ayuda a las personas a comprender los aspectos relevantes y a evaluar las opciones disponibles.
#
# 3. **Registro y Documentación:** Los reportes actúan como una forma de registro y documentación. Ayudan a mantener un historial de eventos, investigaciones, proyectos y actividades, lo que puede ser útil para futuras referencias o auditorías.
#
# 4. **Seguimiento de Proyectos:** En contextos de proyectos, los informes periódicos permiten el seguimiento del progreso y la identificación de problemas o desviaciones en un proyecto. Esto es vital para la gestión de proyectos exitosa.
#
# 5. **Rendición de Cuentas:** Los informes pueden servir para rendir cuentas. En organizaciones y empresas, los empleados y equipos a menudo deben informar sobre su desempeño y resultados a los superiores o a los accionistas.
#
# 6. **Evaluación de Resultados:** Los informes son esenciales para evaluar los resultados de investigaciones, experimentos, encuestas y estudios. Permiten a otros investigadores o interesados revisar y validar los resultados.
#
# 7. **Transparencia y Confianza:** La generación de informes transparentes y precisos aumenta la confianza en los datos y hallazgos presentados. Esto es especialmente importante en campos como la ciencia, la salud y las finanzas.
#
# 8. **Legal y Regulatorio:** En muchos sectores, existen regulaciones legales y requisitos regulatorios que exigen la generación de informes precisos y oportunos. No cumplir con estas regulaciones puede tener consecuencias legales.
#
# 9. **Presentación Profesional:** Un buen informe refleja profesionalismo y atención a los detalles. Puede mejorar la reputación de un individuo, equipo o empresa.
#
# 10. **Facilita la Colaboración:** Los informes son herramientas que facilitan la colaboración entre equipos y partes interesadas. Ayudan a todas las partes a estar en la misma página y a trabajar juntas de manera más efectiva.
#
# 11. **Aprendizaje y Mejora Continua:** Los informes pueden servir como una herramienta de aprendizaje. Al revisar proyectos pasados y analizar lo que funcionó y lo que no, se pueden identificar áreas de mejora y aplicar lecciones aprendidas.

# %% [markdown]
# Crearemos un reporte y se entregará al profesor del curso de **Visual Basic** para informarle sobre los alumnos que están inscritos en su curso

# %%
matriculas.sample(5)
# Out:
#      id_alumno  id_curso
# 437        382         6
# 61          12         5
# 13         310         6
# 465        133         1
# 452        162         5

# %%
# Define el ID del curso que estás buscando
id_curso = 13

# Filtra las matrículas para el curso con el ID de curso igual a 15
proxima_clase = matriculas.query('id_curso == {}'.format(id_curso))

proxima_clase
# Out:
#      id_alumno  id_curso
# 22         218        13
# 27         218        13
# 32          34        13
# 55          80        13
# 57          16        13
# 60          12        13
# 122         27        13
# 136         25        13
# 138         14        13
# 151        396        13
# 154        278        13
# 159        212        13
# 167         73        13
# 306         54        13
# 347        157        13
# 354        308        13
# 389        299        13
# 403        282        13
# 407        229        13
# 413        264        13
# 459        224        13
# 469        309        13
# 476        236        13
# 493        336        13
# 507        188        13
# 540        356        13
# 550         98        13
# 604        120        13
# 629        134        13
# 648        141        13
# 699        184        13
# 715        271        13
# 723        361        13
# 736        206        13
# 779        398        13

# %%
#Ralizando la relacion de dos dataframe
proxima_clase = proxima_clase.set_index('id_alumno').join(nombres.set_index('id_alumno'))['nombres'].to_frame()
proxima_clase
# Out:
#               nombres
# id_alumno
# 12               EDER
# 14            ANTONIO
# 16            ALBERTO
# 25           EDMILSON
# 27              PEDRO
# 34               LUAN
# 54              LUCAS
# 73            WILLIAN
# 80               CAIO
# 98           CRISTINA
# 120             MARIA
# 134           DANIELA
# 141          ROSILENE
# 157            VALDIR
# 184            GISELE
# 188           LARISSA
# 206            PAMELA
# 212           EDUARDO
# 218             ERICK
# 218             ERICK
# 224        ELISANGELA
# 229            WAGNER
# 236            INGRID
# 264            MOISES
# 271            ANGELA
# 278            MAICON
# 282           NIVALDO
# 299          NATANAEL
# 308           EDILSON
# 309           VIVIANE
# 336           JULIANA
# 356           MARILIA
# 361           SOLANGE
# 396        ALESSANDRO
# 398           CLAUDIA

# %%
#'id_curso' contiene el ID del curso que deseas buscar
nombre_aula = cursos.loc[id_curso]

# Ahora 'nombre_de_aula' contendrá el nombre del aula para el curso con 'id_curso'
nombre_aula
# Out:
# nombre_curso    (Visual) Basic
# Name: 13, dtype: object

# %%
nombre_aula = nombre_aula.nombre_curso
nombre_aula
# Out:
# '(Visual) Basic'

# %%
proxima_clase.sample(5)
# Out:
#            nombres
# id_alumno
# 264         MOISES
# 120          MARIA
# 361        SOLANGE
# 188        LARISSA
# 34            LUAN

# %%
proxima_clase = proxima_clase.rename(columns={'nombres': 'Alumnos del curso de {}'.format(nombre_aula)})
proxima_clase.sample(5)
# Out:
#           Alumnos del curso de (Visual) Basic
# id_alumno
# 25                                   EDMILSON
# 16                                    ALBERTO
# 299                                  NATANAEL
# 141                                  ROSILENE
# 361                                   SOLANGE

# %% [markdown]
# # **5. Exportar**

# %% [markdown]
# Exportar datos de manera correcta es un proceso esencial en el mundo de la ciencia de datos y la gestión de la información. Asegurar una exportación adecuada de los datos es fundamental por varias razones:
#
# 1. **Preservar la Integridad de los Datos:** Al exportar datos de manera incorrecta, podrías correr el riesgo de perder información importante o distorsionar la estructura de los datos. Una exportación adecuada garantiza que los datos se mantengan íntegros y sin alteraciones.
#
# 2. **Facilitar el Compartir Datos:** La exportación correcta es esencial cuando deseas compartir tus datos con colegas, clientes o la comunidad en general. Un formato de archivo adecuado y una estructura organizada hacen que los datos sean accesibles y comprensibles para otros.
#
# 3. **Análisis y Visualización Efectiva:** Para realizar análisis de datos y crear visualizaciones significativas, es fundamental que los datos se exporten de manera que sea fácil trabajar con ellos. Los datos mal exportados pueden dificultar o incluso imposibilitar el análisis efectivo.
#
# 4. **Cumplimiento Legal y Regulatorio:** En muchos campos, existe la necesidad de cumplir con regulaciones y estándares legales al manejar datos. Una exportación adecuada ayuda a cumplir con estas regulaciones y a mantener la privacidad y seguridad de los datos.
#
# 5. **Migración de Datos:** Cuando cambias de sistemas o plataformas, la exportación adecuada de datos es esencial para la migración sin problemas. Los datos exportados de manera correcta pueden ser importados eficazmente en nuevos sistemas.
#
# 6. **Seguridad de Datos:** La exportación adecuada también implica consideraciones de seguridad. Garantizar que los datos no sean accesibles para personas no autorizadas es vital para proteger la confidencialidad de la información.
#
# 7. **Respuesta a Incidentes y Recuperación de Desastres:** En situaciones de incidentes o desastres, como pérdida de datos, una exportación adecuada puede facilitar la recuperación y la restauración de la información.
#
# 8. **Eficiencia y Rendimiento:** Una exportación adecuada puede afectar el rendimiento de las operaciones de lectura y escritura de datos. El formato y la organización correctos pueden mejorar la eficiencia de las operaciones posteriores.

# %%
matriculas_por_curso
# Out:
#                nombre_curso  Total
# id_curso
# 1                    Python    172
# 5                        C#    123
# 11              Objective-C    105
# 3                       C++     98
# 6                JavaScript     83
# 12                     Lisp     64
# 8                       PHP     50
# 9                       SQL     49
# 4                      Java     43
# 13           (Visual) Basic     35
# 2                         C     18
# 10        Assembly language     13
# 7              Visual Basic      1

# %% [markdown]
#  El método **to_csv** para guardar el DataFrame **matriculas_por_curso** en un archivo CSV llamado 'matriculas_por_curso.csv' en el directorio de trabajo actual. El argumento **index = False** se utiliza para evitar que se incluya el índice del DataFrame en el archivo CSV.

# %%
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index = False)

# %% [markdown]
# El método **to_json** para guardar el DataFrame **matriculas_por_curso** en un archivo JSON llamado 'matriculas_por_curso.json'.

# %%
matriculas_por_curso.to_json('matriculas_por_curso.json')

# %% [markdown]
# El método **to_html** para guardar el DataFrame **matriculas_por_curso** en un archivo HTML llamado 'matriculas_por_curso.html'. El argumento **index = False** se utiliza para evitar que se incluya el índice del DataFrame en la tabla HTML

# %%
matriculas_por_curso.to_html('matriculas_por_curso.html', index = False)

# %% [markdown]
# **Exportando la proxima clase**

# %%
proxima_clase.to_excel('proxima_clase.xlsx', index = False)

# %% [markdown]
# **Leyendo el archivo de Excel.**

# %%
pd.read_excel('proxima_clase.xlsx')
# Out:
#    Alumnos del curso de (Visual) Basic
# 0                                 EDER
# 1                              ANTONIO
# 2                              ALBERTO
# 3                             EDMILSON
# 4                                PEDRO
# 5                                 LUAN
# 6                                LUCAS
# 7                              WILLIAN
# 8                                 CAIO
# 9                             CRISTINA
# 10                               MARIA
# 11                             DANIELA
# 12                            ROSILENE
# 13                              VALDIR
# 14                              GISELE
# 15                             LARISSA
# 16                              PAMELA
# 17                             EDUARDO
# 18                               ERICK
# 19                               ERICK
# 20                          ELISANGELA
# 21                              WAGNER
# 22                              INGRID
# ...

# %% [markdown]
# # **by: Jose Alfredo Ricardez Perez**
